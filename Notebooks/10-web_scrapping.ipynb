# %% [markdown]
# # RESTful APIs

# %%
import requests
resp = requests.get('http://www.elpais.com/')
resp.content[0:500]
# Out:
# b'<!DOCTYPE html><html lang="es"><head><title>EL PA\xc3\x8dS Edici\xc3\xb3n Am\xc3\xa9rica: el peri\xc3\xb3dico global</title><meta name="lang" content="es"/><meta name="author" content="Ediciones El Pa\xc3\xads"/><meta name="robots" content="index,follow"/><meta name="description" content="Noticias de \xc3\xbaltima hora de Am\xc3\xa9rica Latina, M\xc3\xa9xico, Estados Unidos y la actualidad internacional: pol\xc3\xadtica, econom\xc3\xada, deportes, cultura, sociedad, tecnolog\xc3\xada, gente, opini\xc3\xb3n, viajes, moda, televisi\xc3\xb3n, los blogs y las firmas de EL PA\xc3'

# %%
resp.encoding
# Out:
# 'utf-8'

# %%
resp.text
# Out:
# '<!DOCTYPE html><html lang="es"><head><title>EL PAÍS Edición América: el periódico global</title><meta name="lang" content="es"/><meta name="author" content="Ediciones El País"/><meta name="robots" content="index,follow"/><meta name="description" content="Noticias de última hora de América Latina, México, Estados Unidos y la actualidad internacional: política, economía, deportes, cultura, sociedad, tecnología, gente, opinión, viajes, moda, televisión, los blogs y las firmas de EL PAÍS. Además especiales, vídeos, fotos, audios, gráficos, entrevistas y todos los servicios de EL PAÍS."/><meta http-equiv="Refresh" content="900"/><meta name="organization" content="Ediciones EL PAÍS S.L."/><meta property="article:publisher" content="https://www.facebook.com/elpaisamerica/"/><meta property="og:title" content="EL PAÍS Edición América: el periódico global"/><meta property="og:description" content="Noticias de última hora de América Latina, México, Estados Unidos y la actualidad internacional: política, economía, deportes, cultura, sociedad, tecnología, gente, opinión, viajes, moda, televisión, los blogs y las firmas de EL PAÍS. Además especiales, vídeos, fotos, audios, gráficos, entrevistas y todos los servicios de EL PAÍS."/><meta property="og:image" content="https://imagenes.elpais.com/resizer/etWer09EnmuPcVGI7-TAexiicVY=/560x310/arc-anglerfish-eu-central-1-prod-prisa.s3.amazonaws.com/public/PSMME3J7ZBDOHK4S6ZIIFVDEAQ.png"/><meta property="og:image:width" content="560"/><meta property="og:image:height" content="310"/><meta property="og:url" content="https://elpais.com/america/"/><meta property="og:type" content="website"/><meta property="og:site_name" content="El País América"/><meta property="fb:admins" content="851024123, 100008251487379"/><meta property="fb:pages" content="104093274682328"/><meta property="fb:app_id" content="94039431626"/><meta property="twitter:card" content="summary"/><meta property="twitter:site" content="@elpais_america"/><link rel="alternate" href="https://feeds.elpais.com/mrss-s/pages/ep/site/elpais.com/section/america/portada" type="application/rss+xml" title="RSS de la portada de El País América"/><link rel="canonical" href="https://elpais.com/america/"/><meta name="viewport" content="width=device-width, initial-scale=1"/><script type="application/ld+json">[{"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","item":{"@id":"https://elpais.com","name":"EL PAÍS: el periódico global"},"position":1}]},{"@context":"http://schema.org","@type":"WebSite","name":"EL PAÍS Edición América: el periódico global","sameAs":["https://twitter.com/elpais_america","https://www.facebook.com/elpaisamerica"],"description":"Noticias de última hora de América Latina, México, Estados Unidos y la actualidad internacional: política, economía, deportes, cultura, sociedad, tecnología, gente, opinión, viajes, moda, televisión, los blogs y las firmas de EL PAÍS. Además especiales, vídeos, fotos, audios, gráficos, entrevistas y todos los servicios de EL PAÍS.","image":{"@type":"ImageObject","url":"https://imagenes.elpais.com/resizer/etWer09EnmuPcVGI7-TAexiicVY=/560x310/arc-anglerfish-eu-central-1-prod-prisa.s3.amazonaws.com/public/PSMME3J7ZBDOHK4S6ZIIFVDEAQ.png","height":200,"width":200},"url":"https://elpais.com","copyrightHolder":{"@type":"Organization","name":"EL PAÍS Edición América: el periódico global","url":"https://elpais.com","logo":{"@type":"ImageObject","url":"https://imagenes.elpais.com/resizer/etWer09EnmuPcVGI7-TAexiicVY=/560x310/arc-anglerfish-eu-central-1-prod-prisa.s3.amazonaws.com/public/PSMME3J7ZBDOHK4S6ZIIFVDEAQ.png","height":"560","width":"310"},"location":{"@type":"Place","name":"EL PAÍS Edición América: el periódico global","hasMap":"https://www.google.com/maps/dir/40.4373704,-3.62446/EL+PAIS,+S.L,+Calle+Miguel+Yuste,+40,+28037+Madrid/@40.4374475,-3.6264062,17z/data=!3m1!4b1!4m9!4m8!1m1!4e1!1m5!1m1!1s0xd422f0ae374e7f9:0x85a924c5a0085092!2m2!1d-3.6242389!2d40.4374558","url ...

# %%
resp.status_code
# Out:
# 200

# %%
resp = requests.get('http://api.open-notify.org/iss-now.json')
resp.status_code
# Out:
# 200

# %%
resp.content
# Out:
# b'{"message": "success", "iss_position": {"latitude": "40.4186", "longitude": "178.9887"}, "timestamp": 1610189306}'

# %%
import json
pos = json.loads(resp.content)
pos
# Out:
# {'iss_position': {'latitude': '40.4186', 'longitude': '178.9887'},
#  'message': 'success',
#  'timestamp': 1610189306}

# %%
resp.json()
# Out:
# {'iss_position': {'latitude': '40.4186', 'longitude': '178.9887'},
#  'message': 'success',
#  'timestamp': 1610189306}

# %%
import pandas as pd
pd.read_json('http://api.open-notify.org/iss-now.json')
# Out:
#            message  iss_position           timestamp
# latitude   success       46.5610 2021-01-09 10:51:32
# longitude  success     -167.4579 2021-01-09 10:51:32

# %%
my_dict = {
    'Chicago' : "Illinois", 
    "Kansas City" : ["Kansas", "Missouri"]
}

# %%
def get_iss(lat, long, passes):
  resp = requests.get(f'http://api.open-notify.org/iss-pass.json?lat={lat}&lon={long}&n={passes}')
  content = resp.json()
  return content['response']
get_iss(40.0, 3.5, 5)
# Out:
# [{'duration': 253, 'risetime': 1610222336},
#  {'duration': 635, 'risetime': 1610227902},
#  {'duration': 631, 'risetime': 1610233713},
#  {'duration': 554, 'risetime': 1610239610},
#  {'duration': 572, 'risetime': 1610245476}]

# %%
pd.DataFrame(get_iss(40.0, 3.5, 5))
# Out:
#    duration    risetime
# 0       253  1610222336
# 1       635  1610227902
# 2       631  1610233713
# 3       554  1610239610
# 4       572  1610245476

# %% [markdown]
# # Web Scrapping

# %%
 la_url = 'https://aflcio.org/what-unions-do/social-economic-justice/advocacy/legislative-alerts'

# %% [markdown]
# ## BeautifulSoup

# %%
from bs4 import BeautifulSoup
r = requests.get(la_url)
page = r.content
page[:1000]
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">\n  <head>\n    <meta charset="utf-8" /><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"5d4af6f314",applicationID:"54360456"};window.NREUM||(NREUM={}),__nr_require=function(e,t,n){function r(n){if(!t[n]){var i=t[n]={exports:{}};e[n][0].call(i.exports,function(t){var i=e[n][1][t];return r(i||t)},i,i.exports)}return t[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(e,t,n){function r(){}function i(e,t,n){return function(){return o(e,[u.now()].concat(c(arguments)),t?null:th'

# %% [markdown]
# ### Parsers
# ```
# html.parser
# lxml
# html5lib
# ```

# %%
soup = BeautifulSoup(page, 'html5lib')
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={licenseKey:"5d4af6f314",applicationID:"54360456"};window.NREUM||(NREUM={}),__nr_require=function(e,t,n){function r(n){if(!t[n]){var i=t[n]={exports:{}};e[n][0].call(i.exports,function(t){var i=e[n][1][t];return r(i||t)},i,i.exports)}return t[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(e,t,n){function r(){}function i(e,t,n){return function(){return o(e,[u.now()].concat(c(arguments)),t?null

# %%
help(soup.find_all)
# Out:
# Help on method find_all in module bs4.element:
#
# find_all(name=None, attrs={}, recursive=True, text=None, limit=None, **kwargs) method of bs4.BeautifulSoup instance
#     Extracts a list of Tag objects that match the given
#     criteria.  You can specify the name of the Tag and any
#     attributes you want the Tag to have.
#
#     The value of a key-value pair in the 'attrs' map can be a
#     string, a list of strings, a regular expression object, or a
#     callable that takes a string and returns whether or not the
#     string matches for some custom definition of 'matches'. The
#     same is true of the tag name.

# %%
alerts = soup.find_all('div', class_ = 'content-details')

# %%
type(alerts)
# Out:
# bs4.element.ResultSet

# %%
a = []
for alert in alerts:
  a.append({'link': 'http://www.aflcio.org' + alert.a['href'], 
   'title': alert.find('h2', class_ = 'content-title').span.get_text(),
   'time': alert.find('time').get_text()
   })
pd.DataFrame(a)
# Out:
#                                                  link  ...                time
# 0   http://www.aflcio.org/about/advocacy/legislati...  ...   December 14, 2020
# 1   http://www.aflcio.org/about/advocacy/legislati...  ...   December 14, 2020
# 2   http://www.aflcio.org/about/advocacy/legislati...  ...   December 10, 2020
# 3   http://www.aflcio.org/about/advocacy/legislati...  ...    December 9, 2020
# 4   http://www.aflcio.org/about/advocacy/legislati...  ...    December 9, 2020
# 5   http://www.aflcio.org/about/advocacy/legislati...  ...    December 8, 2020
# 6   http://www.aflcio.org/about/advocacy/legislati...  ...    December 4, 2020
# 7   http://www.aflcio.org/about/advocacy/legislati...  ...   November 19, 2020
# 8   http://www.aflcio.org/about/advocacy/legislati...  ...   November 17, 2020
# 9   http://www.aflcio.org/about/advocacy/legislati...  ...   November 17, 2020
# 10  http://www.aflcio.org/about/advocacy/legislati...  ...   November 17, 2020
# 11  http://www.aflcio.org/about/advocacy/legislati...  ...    October 26, 2020
# 12  http://www.aflcio.org/about/advocacy/legislati...  ...    October 22, 2020
# 13  http://www.aflcio.org/about/advocacy/legislati...  ...     October 1, 2020
# 14  http://www.aflcio.org/about/advocacy/legislati...  ...     October 1, 2020
# 15  http://www.aflcio.org/about/advocacy/legislati...  ...     October 1, 2020
# 16  http://www.aflcio.org/about/advocacy/legislati...  ...  September 30, 2020
# 17  http://www.aflcio.org/about/advocacy/legislati...  ...  September 29, 2020
#
# [18 rows x 3 columns]

# %% [markdown]
# ## Pandas

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_accidents_and_disasters_by_death_toll')
tables[4].head()
# Out:
#         Deaths  ...                                           Incident
# 0        20000  ...  Wanggongchang Explosion in Beijing, China in t...
# 1         3000  ...  A lightning bolt caused the Brescia explosion ...
# 2       3,000?  ...  Boiler and ammunition explosion aboard an unid...
# 3  1,400–2,280  ...  Ammunition warehouse explodes and kills almost...
# 4         1950  ...       Halifax Explosion in Nova Scotia, Canada[68]
#
# [5 rows x 3 columns]

# %% [markdown]
# ## Selenium

# %% [markdown]
# http://books.toscrape.com/

# %%
# !pip install kora -q
# Out:
#      |████████████████████████████████| 61kB 3.2MB/s
#      |████████████████████████████████| 61kB 4.4MB/s

# %%
import re
from kora.selenium import wd

# %%
def parseBook(book_link):
  wd.get(book_link)
  text_to_num = {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5}
  book = {
      "Title": wd.find_element_by_xpath("//*[@id='content_inner']/article/div[1]/div[2]/h1").text,
      "Description": wd.find_element_by_xpath("//*[@id='content_inner']/article/p").text,
      "Rating": text_to_num[re.search('.* (One|Two|Three|Four|Five)', wd.find_element_by_xpath("//*[@id='content_inner']/article/div[1]/div[2]/p[3]").get_attribute("class")).group(1)],
      "Stock Status": wd.find_element_by_xpath("//*[@id='content_inner']/article/div[1]/div[2]/p[2]").text,
      "Price": wd.find_element_by_xpath("//*[@id='content_inner']/article/div[1]/div[2]/p[1]").text,
      "Tax": wd.find_element_by_xpath("//*[@id='content_inner']/article/table/tbody/tr[5]/td").text,
      "UPC": wd.find_element_by_xpath("//*[@id='content_inner']/article/table/tbody/tr[1]/td").text,
      "Category": wd.find_element_by_xpath("//*[@id='default']/div/div/ul/li[3]/a").text
  }
  return book

# %%
def parsePage(page_link):
  books = []
  books_link = []
  wd.get(page_link)
  product_pods = wd.find_elements_by_class_name('product_pod')
  for product_pod in product_pods:
    books_link.append(product_pod.find_element_by_tag_name('h3').find_element_by_tag_name('a').get_property('href'))
  for book_link in books_link:
    books.append(parseBook(book_link))
  return books

books = parsePage('http://books.toscrape.com/catalogue/category/books_1/page-1.html')
books

# %%
import requests
def parseSite(pages = -1):
  index = 1
  link_template = 'http://books.toscrape.com/catalogue/category/books_1/page-{index}.html'
  books = []
  while True:
    if pages > 0 and index > pages:
      break
    page_link = link_template.format(index = index)
    print(f'Processing: {page_link}')
    response = requests.get(page_link)
    if not response.ok:
      break
    books = books + parsePage(page_link)
    index += 1
  return books
   
books = parseSite()
print(f'Total books: {len(books)}')
# Out:
# Processing: http://books.toscrape.com/catalogue/category/books_1/page-1.html
# Processing: http://books.toscrape.com/catalogue/category/books_1/page-2.html
# Processing: http://books.toscrape.com/catalogue/category/books_1/page-3.html
# Processing: http://books.toscrape.com/catalogue/category/books_1/page-4.html
# Processing: http://books.toscrape.com/catalogue/category/books_1/page-5.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-25fb818c15df> in <module>()
#      16   return books
#      17
# ---> 18 books = parseSite()
#      19 print(f'Total books: {len(books)}')
#
# <ipython-input-13-25fb818c15df> in parseSite(pages)
#      12     if not response.ok:
#      13       break
# ---> 14     books = books + parsePage(page_link)
#      15     index += 1
#      16   return books
#
# <ipython-input-10-3469b8a2211a> in parsePage(page_link)
#       7     books_link.append(product_pod.find_element_by_tag_name('h3').find_element_by_tag_name('a').get_property('href'))
#       8   for book_link in books_link:
# ----> 9     books.append(parseBook(book_link))
#      10   return books
#      11
#
# <ipython-input-3-00ed36e83f78> in parseBook(book_link)
#       4   book = {
#       5       "Title": wd.find_element_by_xpath("//*[@id='content_inner']/article/div[1]/div[2]/h1").text,
# ----> 6       "Description": wd.find_element_by_xpath("//*[@id='content_inner']/article/p").text,
#       7       "Rating": text_to_num[re.search('.* (One|Two|Three|Four|Five)', wd.find_element_by_xpath("//*[@id='content_inner']/article/div[1]/div[2]/p[3]").get_attribute("class")).group(1)],
#       8       "Stock Status": wd.find_element_by_xpath("//*[@id='content_inner']/article/div[1]/div[2]/p[2]").text,
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /usr/local/lib/python3.6/dist-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      66             return self.request_encode_url(method, url, fields=fields,
#      67                                            headers=headers,
# ---> 68                                            **urlopen_kw)
#      69         else:
#      70             return self.request_encode_body(method, url, fields=fields,
#
# /usr/local/lib/python3.6/dist-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      87             url += '?' + urlencode(fields)
#      88
# ---> 89         return self.urlopen(method, url, **extra_kw)
#      90
#      91     def request_encode_body(self, method, url, fields=None, headers=None,
#
# /usr/local/lib/python3.6/dist-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
