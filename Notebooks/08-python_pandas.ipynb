# %%
import os
from google.colab import drive

# Mount MyDrive in drive_loc inside our colab VM
drive_loc = '/content/gdrive'
drive.mount(drive_loc)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Check we have successfully mount MyDrive
# !ls -la {drive_loc}
# Out:
# total 16
# dr-x------ 2 root root 4096 Dec 12 08:47 .file-revisions-by-id
# drwx------ 4 root root 4096 Dec 12 08:47 MyDrive
# dr-x------ 2 root root 4096 Dec 12 08:47 .shortcut-targets-by-id
# drwx------ 2 root root 4096 Dec 12 08:47 .Trash

# %%
# Create the path where we will store input and output files to guarantee persistence using Google Drive
files_loc = os.path.join(drive_loc, "MyDrive", "Master", "pdsfiles")
# !mkdir -p {files_loc}
# !ls -la {files_loc}
# Out:
# total 0

# %% [markdown]
# **Pandas**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Series

# %%
# Panda Series relies on Numpy arrays
s = pd.Series([4,7,-5,3])
type(s)
# Out:
# pandas.core.series.Series

# %%
# Textual representation of the serie
s
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
# Values in the serie
s.values
# Out:
# array([ 4,  7, -5,  3])

# %%
# Structure of the serie
s.shape
# Out:
# (4,)

# %%
# Serie with indexed column
s2 = pd.Series([4,7,-5,3], index=["row1","row2","row3","row4"])
s2
# Out:
# row1    4
# row2    7
# row3   -5
# row4    3
# dtype: int64

# %%
s2["row3"]
# Out:
# -5

# %%
# Mask
s2 % 2 == 0
# Out:
# row1     True
# row2    False
# row3    False
# row4    False
# dtype: bool

# %%
# Filter elements using a Mask
s2[s2 % 2 == 0]
# Out:
# row1    4
# dtype: int64

# %%
# Apply arithmetic operations to elements in the serie
print(np.exp(s2))
print(s2 * 2)
# Out:
# row1      54.598150
# row2    1096.633158
# row3       0.006738
# row4      20.085537
# dtype: float64
# row1     8
# row2    14
# row3   -10
# row4     6
# dtype: int64

# %%
# Create a serie from a dict
sdata = {"Zaragoza": 2.5e5, "Sevilla": 5e5, "Cordoba": 3e5, "Madrid": 6e6}
s3 = pd.Series(sdata)
s3
# Out:
# Zaragoza     250000.0
# Sevilla      500000.0
# Cordoba      300000.0
# Madrid      6000000.0
# dtype: float64

# %%
# We can get named indices
s3.index
# Out:
# Index(['Cordoba', 'Madrid', 'Sevilla', 'Zaragoza'], dtype='object')

# %%
if not os.path.exists(os.path.join(files_loc, "s3.pkl")):
  print(f'Creating {os.path.join(files_loc, "s3.pkl")}')
  s3.to_pickle(os.path.join(files_loc, "s3.pkl"))
else:
  print(f'{os.path.join(files_loc, "s3.pkl")} already exists')
# Out:
# /content/gdrive/MyDrive/Master/pdsfiles/s3.pkl already exists
# /content/gdrive/MyDrive/Master/pdsfiles/s3.pkl

# %%
# Order using standard format
s3 = pd.Series(sdata).sort_index()
s3
# Out:
# Cordoba      300000.0
# Madrid      6000000.0
# Sevilla      500000.0
# Zaragoza     250000.0
# dtype: float64

# %%
# Order using explicit named indices. Missing indices are values as NaN
s4 = pd.Series(sdata, index=["Madrid", "Cordoba", "Valencia", "Zaragoza"])
s4
# Out:
# Madrid      6000000.0
# Cordoba      300000.0
# Valencia          NaN
# Zaragoza     250000.0
# dtype: float64

# %%
# Get NaN values
s4[pd.isnull(s4)]
# Out:
# Valencia   NaN
# dtype: float64

# %%
# Get NaN values
s4[pd.notnull(s4)]
# Out:
# Madrid      6000000.0
# Cordoba      300000.0
# Zaragoza     250000.0
# dtype: float64

# %%
# Arithmetic operations in series with named indices operates index by index
s3 + s4
# Out:
# Cordoba       600000.0
# Madrid      12000000.0
# Sevilla            NaN
# Valencia           NaN
# Zaragoza      500000.0
# dtype: float64

# %%
# We can decorate Serie and index
s4.name = "Population"
s4.index.name = "Province"
s4
# Out:
# Province
# Madrid      6000000.0
# Cordoba      300000.0
# Valencia          NaN
# Zaragoza     250000.0
# Name: Population, dtype: float64

# %%
# We can search indexes as usual
"Madrid" in s4
# Out:
# True

# %%
# Access to values using name index
print(s4.Madrid)
print(s4["Madrid"])
print(s4[0])
# Out:
# 6000000.0
# 6000000.0
# 6000000.0

# %% [markdown]
# Datafames

# %%
dfdata = {
    "province": ["M", "M", "M", "B", "B"],
    "population": [1.5e6, 2e6, 3e6, 5e6, 1.5e6],
    "year": [1900, 1950, 2000, 1900, 2000]
}

# %%
df = pd.DataFrame(dfdata)
df
# Out:
#   province  population  year
# 0        M   1500000.0  1900
# 1        M   2000000.0  1950
# 2        M   3000000.0  2000
# 3        B   5000000.0  1900
# 4        B   1500000.0  2001

# %%
# Structure of the DataFrame
df.shape
# Out:
# (5, 3)

# %%
df2 = pd.DataFrame(dfdata, columns=["province", "population", "year", "debt"])
df2
# Out:
#   province  population  year debt
# 0        M   1500000.0  1900  NaN
# 1        M   2000000.0  1950  NaN
# 2        M   3000000.0  2000  NaN
# 3        B   5000000.0  1900  NaN
# 4        B   1500000.0  2000  NaN

# %%
# Unlike Series, DataFrame uses a RangeIndex to optimize (similar to range). It is a generator
df2.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Columns are Index type
df2.columns
# Out:
# Index(['province', 'population', 'year', 'debt'], dtype='object')

# %%
# we can access to columns in axis 1 using names
df['population']
# Out:
# 0    1500000.0
# 1    2000000.0
# 2    3000000.0
# 3    5000000.0
# 4    1500000.0
# Name: population, dtype: float64

# %%
# Columns are Series
type(df.population)
# Out:
# pandas.core.series.Series

# %%
# We can add a new column in axis2
df2["second_lang"] = np.nan
df2
# Out:
#   province  population  year debt  second_lang
# 0        M   1500000.0  1900  NaN          NaN
# 1        M   2000000.0  1950  NaN          NaN
# 2        M   3000000.0  2000  NaN          NaN
# 3        B   5000000.0  1900  NaN          NaN
# 4        B   1500000.0  2000  NaN          NaN

# %%
df2["second_lang"]
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: second_lang, dtype: float64

# %%
df2.index = list("abcde")
df2
# Out:
#   province  population  year debt  second_lang
# a        M   1500000.0  1900  NaN          NaN
# b        M   2000000.0  1950  NaN          NaN
# c        M   3000000.0  2000  NaN          NaN
# d        B   5000000.0  1900  NaN          NaN
# e        B   1500000.0  2000  NaN          NaN

# %%
# Rows can be referenced using loc by named index
df2.loc["c"]
# Out:
# province           M
# population     3e+06
# year            2000
# debt             NaN
# second_lang      NaN
# Name: c, dtype: object

# %%
df2.loc[["a", "e"]]
# Out:
#   province  population  year debt  second_lang
# a        M   1500000.0  1900  NaN          NaN
# e        B   1500000.0  2000  NaN          NaN

# %%
# Slicing using numeric index
df2.iloc[2:]
# Out:
#   province  population  year debt  second_lang
# c        M   3000000.0  2000  NaN          NaN
# d        B   5000000.0  1900  NaN          NaN
# e        B   1500000.0  2000  NaN          NaN

# %%
# Slicing using named index
df2.loc["a":"c"]
# Out:
#   province  population  year debt  second_lang
# a        M   1500000.0  1900  NaN          NaN
# b        M   2000000.0  1950  NaN          NaN
# c        M   3000000.0  2000  NaN          NaN

# %%
# DataFrame supports masking to retrieve rows
df2.loc[df2.year > 1950]
# Out:
#   province  population  year debt  second_lang
# c        M   3000000.0  2000  NaN          NaN
# e        B   1500000.0  2000  NaN          NaN

# %%
# We can assign values directly
df2["debt"] = [1, 0, 2, 0.5, 0.7]
df2
# Out:
#   province  population  year  debt  second_lang
# a        M   1500000.0  1900   1.0          NaN
# b        M   2000000.0  1950   0.0          NaN
# c        M   3000000.0  2000   2.0          NaN
# d        B   5000000.0  1900   0.5          NaN
# e        B   1500000.0  2000   0.7          NaN

# %%
# We can assign values using a serie with named indices
val = pd.Series([.1, .6, .9], index=["b", "d", "e"])
df2["debt"] = val
df2
# Out:
#   province  population  year  debt  second_lang
# a        M   1500000.0  1900   NaN          NaN
# b        M   2000000.0  1950   0.1          NaN
# c        M   3000000.0  2000   NaN          NaN
# d        B   5000000.0  1900   0.6          NaN
# e        B   1500000.0  2000   0.9          NaN

# %%
df2["capital"] = df2["province"] == "M"
df2["debt_per_capita"] = df2["debt"] / df2["population"]
df2
# Out:
#   province  population  year  debt  second_lang  capital  debt_per_capita
# a        M   1500000.0  1900   1.0          NaN     True     6.666667e-07
# b        M   2000000.0  1950   0.0          NaN     True     0.000000e+00
# c        M   3000000.0  2000   2.0          NaN     True     6.666667e-07
# d        B   5000000.0  1900   0.5          NaN    False     1.000000e-07
# e        B   1500000.0  2000   0.7          NaN    False     4.666667e-07

# %% [markdown]
# Save to and Read from disk

# %%
df2.to_pickle(os.path.join(files_loc, "df2.pkl"))
df2 = pd.read_pickle(os.path.join(files_loc, "df2.pkl"))
df2
# Out:
#   province  population  year  debt  second_lang  capital  debt_per_capita
# a        M   1500000.0  1900   1.0          NaN     True     6.666667e-07
# b        M   2000000.0  1950   0.0          NaN     True     0.000000e+00
# c        M   3000000.0  2000   2.0          NaN     True     6.666667e-07
# d        B   5000000.0  1900   0.5          NaN    False     1.000000e-07
# e        B   1500000.0  2000   0.7          NaN    False     4.666667e-07

# %% [markdown]
# Delete Columns

# %%
# Delete an entire column
del df2["second_lang"]
df2
# Out:
#   province  population  year  debt  capital
# a        M   1500000.0  1900   NaN     True
# b        M   2000000.0  1950   0.1     True
# c        M   3000000.0  2000   NaN     True
# d        B   5000000.0  1900   0.6    False
# e        B   1500000.0  2000   0.9    False

# %%
# Describe values (only numeric columns)
df2.describe()
# Out:
#          population    year      debt
# count  5.000000e+00     5.0  3.000000
# mean   2.600000e+06  1950.0  0.533333
# std    1.474788e+06    50.0  0.404145
# min    1.500000e+06  1900.0  0.100000
# 25%    1.500000e+06  1900.0  0.350000
# 50%    2.000000e+06  1950.0  0.600000
# 75%    3.000000e+06  2000.0  0.750000
# max    5.000000e+06  2000.0  0.900000

# %%
# Count of values different to NaN
df2.count()
# Out:
# province      5
# population    5
# year          5
# debt          3
# capital       5
# dtype: int64

# %%
series_temp = pd.Series([1.5, -2.5, 0, 1 , 2], index=df2.index)
series_temp
# Out:
# a    1.5
# b   -2.5
# c    0.0
# d    1.0
# e    2.0
# dtype: float64

# %%
s5 = pd.Series(np.arange(5), index=list("jduvk"))
s5
# Out:
# j    0
# d    1
# u    2
# v    3
# k    4
# dtype: int64

# %%
s6 = s5.drop(["d", "k"])
s6
# Out:
# j    0
# u    2
# v    3
# dtype: int64

# %%
# This mechanism fails if requested index does not exist
s6b = s5.loc[["d", "k"]]
s6b
# Out:
# d    1
# k    4
# dtype: int64

# %%
# This mechanism protects if requested index does not exist
s6b = s5[s5.index.intersection(["d", "k"])]
s6b
# Out:
# d    1
# k    4
# dtype: int64

# %%
# Drop removes, by default, from axis 0
df2 = df2.drop("capital", axis=1)
df2
# Out:
#   province  population  year  debt  second_lang  debt_per_capita
# a        M   1500000.0  1900   1.0          NaN     6.666667e-07
# b        M   2000000.0  1950   0.0          NaN     0.000000e+00
# c        M   3000000.0  2000   2.0          NaN     6.666667e-07
# d        B   5000000.0  1900   0.5          NaN     1.000000e-07
# e        B   1500000.0  2000   0.7          NaN     4.666667e-07

# %% [markdown]
# Deep Copy

# %%
df_detour = pd.DataFrame({"x" : [1,2]})
df_detour
# Out:
#    x
# 0  1
# 1  2

# %%
df_sub = df_detour.iloc[0:1]
df_sub
# Out:
#    x
# 0  1

# %%
df_sub.x = -1
df_sub
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#    x
# 0 -1

# %%
df_detour
# Out:
#    x
# 0 -1
# 1  2

# %%
# Using deep copy
df_detour = pd.DataFrame({"x" : [1,2]})
df_sub = df_detour.iloc[0:1].copy()
df_sub.x = -1
df_detour
# Out:
#    x
# 0  1
# 1  2

# %% [markdown]
# Masking in Dataframes

# %%
df2[(df2.year > 1950) & (df2.debt > 0.5)]
# Out:
#   province  population  year  debt  second_lang  capital  debt_per_capita
# c        M   3000000.0  2000   2.0          NaN     True     6.666667e-07
# e        B   1500000.0  2000   0.7          NaN    False     4.666667e-07

# %%
recent_provinces = df2.year > 1950
debt_provinces = df2.debt > 0.5
df2[recent_provinces & debt_provinces]
# Out:
#   province  population  year  debt  second_lang  capital  debt_per_capita
# c        M   3000000.0  2000   2.0          NaN     True     6.666667e-07
# e        B   1500000.0  2000   0.7          NaN    False     4.666667e-07

# %% [markdown]
# Functions in DataFrame

# %%
np.sqrt(df2.population)
# Out:
# a    1224.744871
# b    1414.213562
# c    1732.050808
# d    2236.067977
# e    1224.744871
# Name: population, dtype: float64

# %%
df4 = pd.DataFrame(np.random.randn(4,3) * 17 + 15, columns = list("bde"), index = list("BMPZ"))
df4
# Out:
#            b          d          e
# B  17.423933  -9.973414   6.706392
# M  17.615490  31.091158  14.653732
# P  26.393657  28.792090   4.683774
# Z  27.819054  33.263662  19.828707

# %%
# Apply functions on series. By default use columns (axis 0)
df4.apply(lambda serie: serie.max() - serie.min())
# Out:
# b    10.395121
# d    43.237076
# e    15.144934
# dtype: float64

# %%
# Apply functions on series using rows (axis 1)
df4.apply(lambda serie: serie.max() - serie.min(), axis = 1)
# Out:
# B    27.397347
# M    16.437426
# P    24.108316
# Z    13.434954
# dtype: float64

# %%
# Apply functions on elements
df4.applymap(lambda element: element % 10)
# Out:
#           b         d         e
# B  7.423933  0.026586  6.706392
# M  7.615490  1.091158  4.653732
# P  6.393657  8.792090  4.683774
# Z  7.819054  3.263662  9.828707

# %%
def f(serie):
    return pd.Series([serie.max() - serie.min()], index = ["result"])
df4.apply(f)
# Out:
#                 b          d          e
# result  10.395121  43.237076  15.144934

# %%
def f(serie):
    return pd.Series([serie.max(), serie.min()], index = ["max", "min"])
df4.apply(f)
# Out:
#              b          d          e
# max  27.819054  33.263662  19.828707
# min  17.423933  -9.973414   4.683774

# %% [markdown]
# Iterate DataFrames

# %%
for item in df4.items():
    print(item)
# Out:
# ('b', B    17.423933
# M    17.615490
# P    26.393657
# Z    27.819054
# Name: b, dtype: float64)
# ('d', B    -9.973414
# M    31.091158
# P    28.792090
# Z    33.263662
# Name: d, dtype: float64)
# ('e', B     6.706392
# M    14.653732
# P     4.683774
# Z    19.828707
# Name: e, dtype: float64)

# %% [markdown]
# Sorting

# %%
df4.sort_index()
# Out:
#            b          d          e
# B  17.423933  -9.973414   6.706392
# M  17.615490  31.091158  14.653732
# P  26.393657  28.792090   4.683774
# Z  27.819054  33.263662  19.828707

# %%
df4.sort_index(ascending = False)
# Out:
#            b          d          e
# Z  27.819054  33.263662  19.828707
# P  26.393657  28.792090   4.683774
# M  17.615490  31.091158  14.653732
# B  17.423933  -9.973414   6.706392

# %%
df4.sort_index(axis = 1, ascending = False)
# Out:
#            e          d          b
# B   6.706392  -9.973414  17.423933
# M  14.653732  31.091158  17.615490
# P   4.683774  28.792090  26.393657
# Z  19.828707  33.263662  27.819054

# %%
df4.sort_values(by="e", ascending=False)
# Out:
#            b          d          e
# Z  27.819054  33.263662  19.828707
# M  17.615490  31.091158  14.653732
# B  17.423933  -9.973414   6.706392
# P  26.393657  28.792090   4.683774

# %%
df4.sort_values(by=["e", "b"])
# Out:
#            b          d          e
# P  26.393657  28.792090   4.683774
# B  17.423933  -9.973414   6.706392
# M  17.615490  31.091158  14.653732
# Z  27.819054  33.263662  19.828707

# %% [markdown]
# Ranking

# %%
s1 = pd.Series(np.random.randint(7, size=7), index=list("abcdefg"))
s1
# Out:
# a    4
# b    4
# c    2
# d    6
# e    4
# f    1
# g    4
# dtype: int64

# %%
s1.rank()
# Out:
# a    4.5
# b    4.5
# c    2.0
# d    7.0
# e    4.5
# f    1.0
# g    4.5
# dtype: float64

# %%
salaries = pd.Series([150000, 90000, 120000, 30000, 10000, 5000, 40000, 50000, 80000, 35000, 14000, 270000])
salaries
# Out:
# 0     150000
# 1      90000
# 2     120000
# 3      30000
# 4      10000
# 5       5000
# 6      40000
# 7      50000
# 8      80000
# 9      35000
# 10     14000
# 11    270000
# dtype: int64

# %%
# Top 3
salaries.sort_values(ascending=False)[:3]
# Out:
# 11    270000
# 0     150000
# 2     120000
# dtype: int64

# %%
# Salaries over the percentile
def top_earners(salaries, percentile=0.9):
  is_top_earner = salaries.rank(pct=True) > percentile
  return salaries[is_top_earner]

print(f"Salaries over 90%:\n {top_earners(salaries)}")
print(f"Salaries over 80%:\n {top_earners(salaries, .8)}")
# Out:
# Salaries over 90%:
#  0     150000
# 11    270000
# dtype: int64
# Salaries over 80%:
#  0     150000
# 2     120000
# 11    270000
# dtype: int64

# %%
x = pd.Series([1.2, np.nan, 4, np.nan, 9], index = list("abcde"))
y = pd.Series([5, 3, 7, np.nan, 14], index = list("abcde"))
df = pd.DataFrame([x, y], index=["x", "y"]).T
df
# Out:
#      x     y
# a  1.2   5.0
# b  NaN   3.0
# c  4.0   7.0
# d  NaN   NaN
# e  9.0  14.0

# %%
df.sum()
# Out:
# x    14.2
# y    29.0
# dtype: float64

# %%
df.mean()
# Out:
# x    4.733333
# y    7.250000
# dtype: float64

# %%
s7 = pd.Series(list("gtcaaaagcttcga"))
s7.unique()
# Out:
# array(['g', 't', 'c', 'a'], dtype=object)

# %%
s7.value_counts()
# Out:
# a    5
# c    3
# t    3
# g    3
# dtype: int64

# %%
s7[s7.isin(["a", "g"])]
# Out:
# 0     g
# 3     a
# 4     a
# 5     a
# 6     a
# 7     g
# 12    g
# 13    a
# dtype: object

# %% [markdown]
# Work with NaN values

# %%
string_data = pd.Series(["Ma", "Lu", "Ca", "Va", np.nan])
string_data[string_data.notnull()]
# Out:
# 0    Ma
# 1    Lu
# 2    Ca
# 3    Va
# dtype: object

# %%
string_data[-string_data.isnull()]
# Out:
# 0    Ma
# 1    Lu
# 2    Ca
# 3    Va
# dtype: object

# %%
df5 = pd.DataFrame([
  [1, 2, 3],
  [np.nan, 8, 7],
  [4, np.nan, 90],
  [67, 42, 53]          
], columns = list("abc"))
df5
# Out:
#       a     b   c
# 0   1.0   2.0   3
# 1   NaN   8.0   7
# 2   4.0   NaN  90
# 3  67.0  42.0  53

# %%
df5[df5["a"].notnull()]
# Out:
#       a     b   c
# 0   1.0   2.0   3
# 2   4.0   NaN  90
# 3  67.0  42.0  53

# %%
# Return columns with any values not null
df5.notnull().any()
# Out:
# a    True
# b    True
# c    True
# dtype: bool

# %%
# Return columns with all values not null
df5.notnull().all()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
# Remove rows with a NaN value
df5.dropna()
# Out:
#       a     b   c
# 0   1.0   2.0   3
# 3  67.0  42.0  53

# %%
df5.dropna(thresh = 2)
# Out:
#       a     b   c
# 0   1.0   2.0   3
# 1   NaN   8.0   7
# 2   4.0   NaN  90
# 3  67.0  42.0  53

# %%
# Fill NaN with default value
df5.fillna(0)
# Out:
#       a     b   c
# 0   1.0   2.0   3
# 1   0.0   8.0   7
# 2   4.0   0.0  90
# 3  67.0  42.0  53

# %%
# Fill NaN with specific value per column
df5.fillna({
  "a": 0,
  "b": 10,
  "c": 20  
})
# Out:
#       a     b   c
# 0   1.0   2.0   3
# 1   0.0   8.0   7
# 2   4.0  10.0  90
# 3  67.0  42.0  53

# %%
# Fill NaN with previous value in the serie
df5.fillna(method="ffill")
# Out:
#       a     b   c
# 0   NaN   2.0   3
# 1   NaN   8.0   7
# 2   4.0   8.0  90
# 3  67.0  42.0  53

# %%
# Fill NaN with next value in the serie
df5.fillna(method="bfill")
# Out:
#       a     b   c
# 0   4.0   2.0   3
# 1   4.0   8.0   7
# 2   4.0  42.0  90
# 3  67.0  42.0  53

# %%
# Fill NaN with media of the serie
df5.fillna(df5.mean())
# Out:
#       a          b   c
# 0   1.0   2.000000   3
# 1  24.0   8.000000   7
# 2   4.0  17.333333  90
# 3  67.0  42.000000  53

# %% [markdown]
# Working with data sinks

# %%
# !wget https://bit.ly/ks-pds-csv2 -O {files_loc}/T100_AIRLINES.csv
# Out:
# --2020-12-12 12:39:19--  https://bit.ly/ks-pds-csv2
# Resolving bit.ly (bit.ly)... 67.199.248.11, 67.199.248.10
# Connecting to bit.ly (bit.ly)|67.199.248.11|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://drive.google.com/uc?export=view&id=10TunyfQbYFZv8P0rStl4Z1okztqPa3S5 [following]
# --2020-12-12 12:39:19--  https://drive.google.com/uc?export=view&id=10TunyfQbYFZv8P0rStl4Z1okztqPa3S5
# Resolving drive.google.com (drive.google.com)... 108.177.97.139, 108.177.97.100, 108.177.97.101, ...
# Connecting to drive.google.com (drive.google.com)|108.177.97.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-cc-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9sgft2q82upru3b59u56cs1ov3d6r72v/1607776725000/09168289428562857012/*/10TunyfQbYFZv8P0rStl4Z1okztqPa3S5?e=view [following]
# Warning: wildcards not supported in HTTP.
# --2020-12-12 12:39:20--  https://doc-14-cc-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9sgft2q82upru3b59u56cs1ov3d6r72v/1607776725000/09168289428562857012/*/10TunyfQbYFZv8P0rStl4Z1okztqPa3S5?e=view
# Resolving doc-14-cc-docs.googleusercontent.com (doc-14-cc-docs.googleusercontent.com)... 74.125.203.132, 2404:6800:4008:c03::84
# Connecting to doc-14-cc-docs.googleusercontent.com (doc-14-cc-docs.googleusercontent.com)|74.125.203.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘/content/gdrive/MyDrive/Master/pdsfiles/T100_AIRLINES.csv’
#
# /content/gdrive/MyD     [  <=>               ]   9.32M  26.9MB/s    in 0.3s
#
# 2020-12-12 12:39:21 (26.9 MB/s) - ‘/content/gdrive/MyDrive/Master/pdsfiles/T100_AIRLINES.csv’ saved [9777233]

# %%
csv = "/content/gdrive/MyDrive/Master/pdsfiles/T100_AIRLINES.csv"

# %%
traffic_df = pd.read_csv(csv)
traffic_df.head()
# Out:
#    DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED  ...  CLASS  Unnamed: 43
# 0                   0.0                   1.0  ...      L          NaN
# 1                   0.0                   1.0  ...      L          NaN
# 2                   0.0                   1.0  ...      L          NaN
# 3                   0.0                   1.0  ...      L          NaN
# 4                   0.0                   1.0  ...      L          NaN
#
# [5 rows x 44 columns]

# %%
traffic_df.iloc[:1000].to_excel(os.path.join(files_loc, "T100_AIRLINES.xls"))

# %%
import sqlite3
conn = sqlite3.connect(os.path.join(files_loc, "T100_AIRLINES.db"))
traffic_df.to_sql("traffic", conn, if_exists="replace")
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
traffic_df.head(2).to_dict()
# Out:
# {'AIRCRAFT_CONFIG': {0: 1, 1: 1},
#  'AIRCRAFT_GROUP': {0: 6, 1: 6},
#  'AIRCRAFT_TYPE': {0: 622, 1: 622},
#  'AIRLINE_ID': {0: 21040.0, 1: 21040.0},
#  'AIR_TIME': {0: 0.0, 1: 0.0},
#  'CARRIER': {0: '02Q', 1: '02Q'},
#  'CARRIER_GROUP': {0: 0, 1: 0},
#  'CARRIER_GROUP_NEW': {0: 0.0, 1: 0.0},
#  'CARRIER_NAME': {0: 'Titan Airways', 1: 'Titan Airways'},
#  'CLASS': {0: 'L', 1: 'L'},
#  'DEPARTURES_PERFORMED': {0: 1.0, 1: 1.0},
#  'DEPARTURES_SCHEDULED': {0: 0.0, 1: 0.0},
#  'DEST': {0: 'MCO', 1: 'STN'},
#  'DEST_AIRPORT_ID': {0: 13204, 1: 15018},
#  'DEST_AIRPORT_SEQ_ID': {0: 1320402, 1: 1501806},
#  'DEST_CITY_MARKET_ID': {0: 31454, 1: 30730},
#  'DEST_CITY_NAME': {0: 'Orlando, FL', 1: 'London, United Kingdom'},
#  'DEST_COUNTRY': {0: 'US', 1: 'GB'},
#  'DEST_COUNTRY_NAME': {0: 'United States', 1: 'United Kingdom'},
#  'DEST_WAC': {0: 33, 1: 493},
#  'DISTANCE': {0: 3160.0, 1: 4360.0},
#  'DISTANCE_GROUP': {0: 7, 1: 9},
#  'FREIGHT': {0: 0.0, 1: 0.0},
#  'MAIL': {0: 0.0, 1: 0.0},
#  'MONTH': {0: 1, 1: 1},
#  'ORIGIN': {0: 'TER', 1: 'MCO'},
#  'ORIGIN_AIRPORT_ID': {0: 15174, 1: 13204},
#  'ORIGIN_AIRPORT_SEQ_ID': {0: 1517403, 1: 1320402},
#  'ORIGIN_CITY_MARKET_ID': {0: 32946, 1: 31454},
#  'ORIGIN_CITY_NAME': {0: 'Lajes, Portugal', 1: 'Orlando, FL'},
#  'ORIGIN_COUNTRY': {0: 'PT', 1: 'US'},
#  'ORIGIN_COUNTRY_NAME': {0: 'Portugal', 1: 'United States'},
#  'ORIGIN_WAC': {0: 469, 1: 33},
#  'PASSENGERS': {0: 76.0, 1: 0.0},
#  'PAYLOAD': {0: 26543.0, 1: 26543.0},
#  'QUARTER': {0: 1, 1: 1},
#  'RAMP_TO_RAMP': {0: 0.0, 1: 0.0},
#  'REGION': {0: 'I', 1: 'I'},
#  'SEATS': {0: 76.0, 1: 76.0},
#  'UNIQUE_CARRIER': {0: '02Q', 1: '02Q'},
#  'UNIQUE_CARRIER_ENTITY': {0: '71004', 1: '71004'},
#  'UNIQUE_CARRIER_NAME': {0: 'Titan Airways', 1: 'Titan Airways'},
#  'Unnamed: 43': {0: nan, 1: nan},
#  'YEAR': {0: 2020, 1: 2020}}

# %%
traffic_df.head(2).to_json()
# Out:
# '{"DEPARTURES_SCHEDULED":{"0":0.0,"1":0.0},"DEPARTURES_PERFORMED":{"0":1.0,"1":1.0},"PAYLOAD":{"0":26543.0,"1":26543.0},"SEATS":{"0":76.0,"1":76.0},"PASSENGERS":{"0":76.0,"1":0.0},"FREIGHT":{"0":0.0,"1":0.0},"MAIL":{"0":0.0,"1":0.0},"DISTANCE":{"0":3160.0,"1":4360.0},"RAMP_TO_RAMP":{"0":0.0,"1":0.0},"AIR_TIME":{"0":0.0,"1":0.0},"UNIQUE_CARRIER":{"0":"02Q","1":"02Q"},"AIRLINE_ID":{"0":21040.0,"1":21040.0},"UNIQUE_CARRIER_NAME":{"0":"Titan Airways","1":"Titan Airways"},"UNIQUE_CARRIER_ENTITY":{"0":"71004","1":"71004"},"REGION":{"0":"I","1":"I"},"CARRIER":{"0":"02Q","1":"02Q"},"CARRIER_NAME":{"0":"Titan Airways","1":"Titan Airways"},"CARRIER_GROUP":{"0":0,"1":0},"CARRIER_GROUP_NEW":{"0":0.0,"1":0.0},"ORIGIN_AIRPORT_ID":{"0":15174,"1":13204},"ORIGIN_AIRPORT_SEQ_ID":{"0":1517403,"1":1320402},"ORIGIN_CITY_MARKET_ID":{"0":32946,"1":31454},"ORIGIN":{"0":"TER","1":"MCO"},"ORIGIN_CITY_NAME":{"0":"Lajes, Portugal","1":"Orlando, FL"},"ORIGIN_COUNTRY":{"0":"PT","1":"US"},"ORIGIN_COUNTRY_NAME":{"0":"Portugal","1":"United States"},"ORIGIN_WAC":{"0":469,"1":33},"DEST_AIRPORT_ID":{"0":13204,"1":15018},"DEST_AIRPORT_SEQ_ID":{"0":1320402,"1":1501806},"DEST_CITY_MARKET_ID":{"0":31454,"1":30730},"DEST":{"0":"MCO","1":"STN"},"DEST_CITY_NAME":{"0":"Orlando, FL","1":"London, United Kingdom"},"DEST_COUNTRY":{"0":"US","1":"GB"},"DEST_COUNTRY_NAME":{"0":"United States","1":"United Kingdom"},"DEST_WAC":{"0":33,"1":493},"AIRCRAFT_GROUP":{"0":6,"1":6},"AIRCRAFT_TYPE":{"0":622,"1":622},"AIRCRAFT_CONFIG":{"0":1,"1":1},"YEAR":{"0":2020,"1":2020},"QUARTER":{"0":1,"1":1},"MONTH":{"0":1,"1":1},"DISTANCE_GROUP":{"0":7,"1":9},"CLASS":{"0":"L","1":"L"},"Unnamed: 43":{"0":null,"1":null}}'

# %%
df2 = pd.read_excel(os.path.join(files_loc, "T100_AIRLINES.xls"))
df2.head()
# Out:
#    Unnamed: 0  DEPARTURES_SCHEDULED  ...  CLASS  Unnamed: 43
# 0           0                     0  ...      L          NaN
# 1           1                     0  ...      L          NaN
# 2           2                     0  ...      L          NaN
# 3           3                     0  ...      L          NaN
# 4           4                     0  ...      L          NaN
#
# [5 rows x 45 columns]
